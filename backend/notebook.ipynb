# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/catalog_trimmed_priced.csv')

# %%
df.columns
# Out:
# Index(['article_id', 'product_code', 'prod_name', 'product_type_no',
#        'product_type_name', 'product_group_name', 'graphical_appearance_no',
#        'graphical_appearance_name', 'colour_group_code', 'colour_group_name',
#        'perceived_colour_value_id', 'perceived_colour_value_name',
#        'perceived_colour_master_id', 'perceived_colour_master_name',
#        'department_no', 'department_name', 'index_code', 'index_name',
#        'index_group_no', 'index_group_name', 'section_no', 'section_name',
#        'garment_group_no', 'garment_group_name', 'detail_desc', 'price_cents',
#        'currency'],
#       dtype='object')

# %%
type(df['article_id'][0])
# Out:
# numpy.int64

# %%
df['product_group_name'].unique()
# Out:
# array(['Underwear', 'Socks & Tights', 'Accessories', 'Items', 'Unknown',
#        'Shoes', 'Swimwear', 'Nightwear', 'Garment Lower body',
#        'Garment Upper body', 'Garment Full body', 'Bags', 'Furniture',
#        'Garment and Shoe care', 'Stationery'], dtype=object)

# %%
df
# Out:
#       article_id  product_code                prod_name  product_type_no  \
# 0      110065002        110065        OP T-shirt (Idro)              306
# 1      111565003        111565      20 den 1p Stockings              302
# 2      111609001        111609        200 den 1p Tights              304
# 3      126589007        126589                  2p Claw               72
# 4      130035001        130035           Black Umbrella              532
# ...          ...           ...                      ...              ...
# 3995   943256001        943256            SC NET TIGHTS              304
# 3996   943879001        943879         Blake N-Slip (J)              293
# 3997   947060001        947060           JAKE WOVEN 2PK              296
# 3998   947538001        947538  Flirty Fries earcuff pk               70
# 3999   953450001        953450   5pk regular Placement1              302
#
#      product_type_name product_group_name  graphical_appearance_no  \
# ...

# %%
df['garment_group_name']
# Out:
# 0       Under-, Nightwear
# 1        Socks and Tights
# 2        Socks and Tights
# 3             Accessories
# 4             Accessories
#               ...
# 3995              Unknown
# 3996    Under-, Nightwear
# 3997    Under-, Nightwear
# 3998          Accessories
# 3999     Socks and Tights
# Name: garment_group_name, Length: 4000, dtype: object
